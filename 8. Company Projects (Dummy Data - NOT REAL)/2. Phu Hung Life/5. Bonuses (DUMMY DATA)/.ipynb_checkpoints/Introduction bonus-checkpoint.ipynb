# %%
import numpy as np
import pandas as pd
import pyodbc as pyo
import sqlalchemy as sa
import numpy as np
import math
import datetime
import datetime as dt
from datetime import timedelta
#Kết nối SV_UAT (SQL_SV64)
connection_uri_UAT = (
    "mssql+pyodbc://PHLHCMHOPPBI02\PBIRS/PowerBI?driver=ODBC+Driver+17+for+SQL+Server"
)
conn = sa.create_engine(connection_uri_UAT)

# %% [markdown]
# <h3> 1. Lấy bảng

# %% [markdown]
# <h5>1.1. Lấy bảng AgentInfo

# %%
cutoff = input("Nhập kỳ CUTOFF cuối tháng YYYYMMDD: ")
# Out:
# Nhập kỳ CUTOFF cuối tháng YYYYMMDD: 20230131

# %%
agent_query = f"""\n
SELECT * FROM [DPO].[Main_AGENT_INFO_DA_CUTOFF]
WHERE CUTOFF = {cutoff}
"""
agent_table = pd.read_sql(agent_query, conn)
agent_table
# Out:
#       Area_Name               Sales_Unit Sales_Unit_Code  \
# 0           TAA             Ngô Anh Tài           AD082
# 1           ABT   Nguyễn Thị Tố Quyên           AD786
# 2           EAK       Thiều Quang Mạnh           AD174
# 3           AVP          Văn Hương Giang           AD811
# 4           LAK           Đặng Văn Phan           AD501
# ...         ...                      ...             ...
# 75901       STR          Lục Minh Hiếu           AD409
# 75902       SG1  Lê Nguyễn Ánh Nguyệt           AD752
# 75903       BMT          Võ Tất Thắng           AD088
# 75904       LAN       Trương Thái Tuấn           AD099
# 75905       EAK            Lê Thị Hoài           AD680
#
#       Parent_Supervisor_Code        Parent_Supervisor_Name Supervisor_Code  \
# 0                   60030650      DM - PHẠM THỊ CÚC HOA        60030655
# 1                   60055833  FM - NGUYỄN NGỌC DUY QUANG        60055914
# 2                   60008686          DM - NGUYỄN VĂN KỶ        60019636
# 3                                                     None        60054777
# 4                   60062231            DM - PHAN HỮU SỸ        60075163
# ...                      ...                           ...             ...
# 75901               60002305            FC - LÊ THÀNH DÂN        60000699
# 75902               60070913       DM - NGUYỄN MINH TUẤN        60070705
# 75903                                                 None        60016183
# 75904                   None                          None
# 75905               60020362            RM - ĐỖ THỊ LOAN        60026999
#
#                  Supervisor_Name Agent_Number              Agent_Name  Gender  \
# 0      FM - PHẠM THỊ HỒNG ANH     60060890      NGUYỄN HOÀNG ANH    Male
# 1        FM - HUỲNH THANH TUẤN     60060917        PHẠM BÁ KHƯƠNG    Male
# 2          FC - NGUYỄN THỊ NỤ     60021398       NGUYỄN THỊ MẬU  Female
# 3             DM - ĐÀO THỊ NGA     60055999       NGUYỄN THỊ BIÊN  Female
# 4            FM - ĐẶNG THỊ SOA     60075691       LÊ THỊ KHÁNH LY  Female
# ...                          ...          ...                     ...     ...
# 75901      AM - TRƯƠNG HUY LUẬN     60006002         NGÔ QUỐC TRUNG    Male
# 75902     FC - LÊ TRƯỜNG KHÁNH     60074423  PHAN THỊ TUYẾT HƯƠNG  Female
# 75903   FC - KIỀU THỊ MỸ LỘC     60016239          LÊ THỊ PHƯỚC  Female
# 75904                       None     60005479         HỒ NGỌC THÔNG    Male
# 75905   FM - NGUYỄN THỊ NGOÃN     60042462       NGUYỄN THỊ XUÂN  Female
#
#        ...    Leader SFC Leader_count Appointed_TAPSU    CUTOFF  \
# 0      ...  60030655                2      2022-06-20  20230131
# 1      ...  60055914                3      2022-06-20  20230131
# 2      ...  60008686                2      2019-06-19  20230131
# 3      ...  60054777                1      2022-01-25  20230131
# 4      ...  60075163                6      2022-12-29  20230131
# ...    ...       ...  ..          ...             ...       ...
# 75901  ...      None                2      2016-09-26  20230131
# 75902  ...  60070913                6      2022-12-12  20230131
# 75903  ...      None                1      2018-08-24  20230131
# 75904  ...      None                0      2016-08-25  20230131
# 75905  ...  60026999                2      2021-05-18  20230131
#
#       First_Appointed Area_Desc TERRITORY HOT Name  Sale_Unit_Grade
# 0                None      None      None     None             None
# 1                None      None      None     None             None
# 2                None      None      None     None             None
# 3                None      None      None     None             None
# 4                None      None      None     None             None
# ...               ...       ...       ...      ...              ...
# 75901            None      None      None     None             None
# 75902            None      None      None     None             None
# 75903            None      None      None     None             None
# 75904            None      None      None     None             None
# 75905            None      None      None     None             None
#
# [75906 rows x 70 columns]

# %% [markdown]
# <h5>1.2 Lấy bảng Commision

# %%
com_query = f"""\n
SELECT * FROM [DPO].[DP_TAGENTCOMM_TEST_CUTOFF]
WHERE CUTOFF = {cutoff}
"""
com_table = pd.read_sql(com_query, conn)
com_table
# Out:
#         Policy No Product Code Premium transaction  \
# 0        80000047         EC01                B522
# 1        80000047         RAC2                B522
# 2        80000047         EC01                B522
# 3        80000047         EC01                B522
# 4        80000047         RAC2                B522
# ...           ...          ...                 ...
# 1264295  80131429         URT5                T642
# 1264296  80131429         URA5                T642
# 1264297  80131429         URC6                T642
# 1264298  80131429         RHS1                T642
# 1264299  80131429         URC5                T642
#
#                Premium transaction name  Premium Collected Collected Date  \
# 0        Premium Collection                      3002000.0     2018-07-13
# 1        Premium Collection                       360000.0     2019-06-25
# 2        Premium Collection                      3002000.0     2019-06-25
# 3        Premium Collection                      3002000.0     2020-06-22
# 4        Premium Collection                       360000.0     2020-06-22
# ...                                 ...                ...            ...
# 1264295  Contract Issue                           620000.0     2022-12-31
# 1264296  Contract Issue                          1074000.0     2022-12-31
# 1264297  Contract Issue                          1182000.0     2022-12-31
# 1264298  Contract Issue                           123000.0     2022-12-31
# 1264299  Contract Issue                           360000.0     2022-12-31
#
#         Applied Premium Date       FYC       RYC  Shared Commission Rate  ...  \
# 0                 2018-07-13       0.0  150000.0                   100.0  ...
# 1                 2019-06-25       0.0   11000.0                   100.0  ...
# 2                 2019-06-25       0.0   60000.0                   100.0  ...
# 3                 2020-06-22       0.0   60000.0                   100.0  ...
# 4                 2020-06-22       0.0   11000.0                   100.0  ...
# ...                      ...       ...       ...                     ...  ...
# 1264295           2022-12-31  217000.0       0.0                   100.0  ...
# 1264296           2022-12-31  376000.0       0.0                   100.0  ...
# 1264297           2022-12-31  414000.0       0.0                   100.0  ...
# 1264298           2022-12-31   25000.0       0.0                   100.0  ...
# 1264299           2022-12-31  126000.0       0.0                   100.0  ...
#
#         Servicing Agent  Commission Agent Transfer Date Proposal Receive Date  \
# 0              60001123          60001123    2017-03-24            2014-06-19
# 1              60001123          60001123    2017-03-24            2014-06-19
# 2              60001123          60001123    2017-03-24            2014-06-19
# 3              60015505          60015505    2020-01-07            2014-06-19
# 4              60015505          60015505    2020-01-07            2014-06-19
# ...                 ...               ...           ...                   ...
# 1264295        60075311          60075311    2022-12-31            2022-12-31
# 1264296        60075311          60075311    2022-12-31            2022-12-31
# 1264297        60075311          60075311    2022-12-31            2022-12-31
# 1264298        60075311          60075311    2022-12-31            2022-12-31
# 1264299        60075311          60075311    2022-12-31            2022-12-31
#
#         Freelook RISK_COMMENCE_DATE Receive Policy date Premium Year  \
# 0         3144.0         2014-06-19          2014-06-24            5
# 1         3144.0         2014-06-19          2014-06-24            6
# 2         3144.0         2014-06-19          2014-06-24            6
# 3         3144.0         2014-06-19          2014-06-24            7
# 4         3144.0         2014-06-19          2014-06-24            7
# ...          ...                ...                 ...          ...
# 1264295     21.0         2022-12-31          2023-01-11            1
# 1264296     21.0         2022-12-31          2023-01-11            1
# 1264297     21.0         2022-12-31          2023-01-11            1
# 1264298     21.0         2022-12-31          2023-01-11            1
# 1264299     21.0         2022-12-31          2023-01-11            1
#
#            CUTOFF RETURN_DATE
# 0        20230131        None
# 1        20230131        None
# 2        20230131        None
# 3        20230131        None
# 4        20230131        None
# ...           ...         ...
# 1264295  20230131        None
# 1264296  20230131        None
# 1264297  20230131        None
# 1264298  20230131        None
# 1264299  20230131        None
#
# [1264300 rows x 31 columns]

# %% [markdown]
# <h3>2. Xây cấu trúc bảng

# %% [markdown]
# <h5>2.1 Lấy ra quan hệ giữa người giới thiệu và được giới thiệu

# %%
introduce_agent = agent_table
introduce_agent = introduce_agent[['Agent Numer of Introducer', 'Agent_Number']]
introduce_agent = introduce_agent.dropna()
introduce_agent = introduce_agent.rename(columns={'Agent Numer of Introducer':"Introducer", 'Agent_Number': "Introducee"})
introduce_agent
# Out:
#       Introducer Introducee
# 0       60030655   60060890
# 1       60055914   60060917
# 3       60054777   60055999
# 4       60075163   60075691
# 5       60035540   60035661
# ...          ...        ...
# 75897   60029911   60031666
# 75898   60055637   60060274
# 75899   60055496   60060709
# 75902   60070705   60074423
# 75905   60026999   60042462
#
# [53362 rows x 2 columns]

# %% [markdown]
# <h5>2.2 Móc lấy thông tin cụ thể của người giới thiệu:

# %%
introduce_info = pd.merge(introduce_agent, agent_table, left_on = 'Introducer', right_on ='Agent_Number', how='left')
introduce_info = introduce_info[['Introducer', 'Agent_Name', 'Grade', 'Agent_Status', 'Date_Appointed', 'Introducee']].\
rename(columns={'Agent_Name':'IntroducerName', 'Grade': 'IntroducerGrade', 'Agent_Status':'IntroducerStatus', 'Date_Appointed':'IntroducerAppointed'})
introduce_info
# Out:
#       Introducer        IntroducerName IntroducerGrade IntroducerStatus  \
# 0       60030655  PHẠM THỊ HỒNG ANH              FM          Enforce
# 1       60055914    HUỲNH THANH TUẤN              FM          Enforce
# 2       60054777         ĐÀO THỊ NGA              DM          Enforce
# 3       60075163        ĐẶNG THỊ SOA              FM          Enforce
# 4       60035540         ĐỖ THỊ HẢI              FC          Enforce
# ...          ...                   ...             ...              ...
# 53357   60029911    NGUYỄN THỊ TRANG              FM          Enforce
# 53358   60055637  LÊ THỊ THANH TUYẾT              FM          Enforce
# 53359   60055496  NGUYỄN HOÀNG TÙNG              FM          Enforce
# 53360   60070705     LÊ TRƯỜNG KHÁNH              FC          Enforce
# 53361   60026999   NGUYỄN THỊ NGOÃN              FM          Enforce
#
#       IntroducerAppointed Introducee
# 0              2021-01-11   60060890
# 1              2022-01-22   60060917
# 2              2022-08-27   60055999
# 3              2022-12-21   60075691
# 4              2020-12-25   60035661
# ...                   ...        ...
# 53357          2020-09-17   60031666
# 53358          2022-08-10   60060274
# 53359          2022-01-12   60060709
# 53360          2022-10-19   60074423
# 53361          2020-06-29   60042462
#
# [53362 rows x 6 columns]

# %% [markdown]
# <h5>2.3 Móc lấy thông tin cụ thể người được giới thiệu:

# %%
introducee_info = pd.merge(introduce_info, agent_table, left_on = 'Introducee', right_on ='Agent_Number', how ='left')
introducee_info = introducee_info[['Introducer', 'IntroducerName', 'IntroducerGrade', 'IntroducerStatus','IntroducerAppointed', 
        'Introducee', 'Agent_Name', 'Grade', 'Agent_Status', 'Date_Appointed', 'Area_Name', 'Sales_Unit_Code', 'Sales_Unit', 'CUTOFF']].\
rename(columns={'Agent_Name':'IntroduceeName', 'Grade': 'IntroduceeGrade', 'Agent_Status':'IntroduceeStatus', 'Date_Appointed':'IntroduceeAppointed',
               'Sales_Unit':"AD_Name", 'Sales_Unit_Code':'AD_Code'})
introducee_info['Appointed_Temp'] = np.where(introducee_info['IntroduceeAppointed'].dt.day > 10, 
        introducee_info['IntroduceeAppointed'] + pd.DateOffset(months=1), introducee_info['IntroduceeAppointed'])
introducee_info['Appointed_Temp'] = introducee_info['Appointed_Temp'].dt.floor('d') + pd.offsets.MonthEnd(0) - pd.offsets.MonthBegin(1)
introducee_info['Date_On_Set'] = pd.to_datetime(introducee_info['CUTOFF'].str[:4]+"-"+introducee_info['CUTOFF'].str[4:6]+"-"+introducee_info['CUTOFF'].str[6:])
introducee_info['Date_Temp'] = introducee_info['Date_On_Set'].dt.floor('d') + pd.offsets.MonthEnd(0) - pd.offsets.MonthBegin(1)
introducee_info['Length of Service(Months)'] = (introducee_info['Date_Temp'].dt.to_period('M').astype('int64') +1 ) - introducee_info['Appointed_Temp'].dt.to_period('M').astype('int64')
introducee_info = introducee_info.loc[:, ~introducee_info.columns.isin(['Date_On_Set', 'Date_Temp', 'Appointed_Temp'])]
introducee_info
# Out:
#       Introducer        IntroducerName IntroducerGrade IntroducerStatus  \
# 0       60030655  PHẠM THỊ HỒNG ANH              FM          Enforce
# 1       60055914    HUỲNH THANH TUẤN              FM          Enforce
# 2       60054777         ĐÀO THỊ NGA              DM          Enforce
# 3       60075163        ĐẶNG THỊ SOA              FM          Enforce
# 4       60035540         ĐỖ THỊ HẢI              FC          Enforce
# ...          ...                   ...             ...              ...
# 53357   60029911    NGUYỄN THỊ TRANG              FM          Enforce
# 53358   60055637  LÊ THỊ THANH TUYẾT              FM          Enforce
# 53359   60055496  NGUYỄN HOÀNG TÙNG              FM          Enforce
# 53360   60070705     LÊ TRƯỜNG KHÁNH              FC          Enforce
# 53361   60026999   NGUYỄN THỊ NGOÃN              FM          Enforce
#
#       IntroducerAppointed Introducee          IntroduceeName IntroduceeGrade  \
# 0              2021-01-11   60060890      NGUYỄN HOÀNG ANH              FC
# 1              2022-01-22   60060917        PHẠM BÁ KHƯƠNG              FC
# 2              2022-08-27   60055999       NGUYỄN THỊ BIÊN              FC
# 3              2022-12-21   60075691       LÊ THỊ KHÁNH LY              FC
# 4              2020-12-25   60035661             LÒ VĂN TÂM              FC
# ...                   ...        ...                     ...             ...
# 53357          2020-09-17   60031666         PHAN VĂN THẮNG              FC
# 53358          2022-08-10   60060274            MAI THỊ VÂN              FC
# 53359          2022-01-12   60060709           CHU THỊ THOA              FC
# 53360          2022-10-19   60074423  PHAN THỊ TUYẾT HƯƠNG              FC
# 53361          2020-06-29   60042462       NGUYỄN THỊ XUÂN              FC
#
#       IntroduceeStatus IntroduceeAppointed Area_Name AD_Code  \
# 0              Enforce          2022-06-20       TAA   AD082
# 1           Terminated          2022-06-20       ABT   AD786
# 2              Enforce          2022-01-25       AVP   AD811
# 3              Enforce          2022-12-29       LAK   AD501
# 4           Terminated          2020-12-25       AHN   AD586
# ...                ...                 ...       ...     ...
# 53357          Enforce          2020-10-21       DKN   AD824
# 53358       Terminated          2022-06-16       KYA   AD552
# 53359       Terminated          2022-06-20       SG1   AD715
# 53360          Enforce          2022-12-12       SG1   AD752
# 53361          Enforce          2021-06-11       EAK   AD680
#
#                        AD_Name    CUTOFF  Length of Service(Months)
# 0                 Ngô Anh Tài  20230131                          7
# 1       Nguyễn Thị Tố Quyên  20230131                          7
# 2              Văn Hương Giang  20230131                         12
# 3               Đặng Văn Phan  20230131                          1
# 4           Nguyễn Ngọc Ánh  20230131                         25
# ...                        ...       ...                        ...
# 53357       Võ Thị Thanh Nga  20230131                         27
# 53358            Tăng Thị Bé  20230131                          7
# 53359        Phạm Minh Hoàng  20230131                          7
# 53360  Lê Nguyễn Ánh Nguyệt  20230131                          1
# 53361            Lê Thị Hoài  20230131                         19
#
# [53362 rows x 15 columns]

# %% [markdown]
# <h3>3. Tính hoa hồng

# %% [markdown]
# <h5>3.1 Lấy ra ngày đầu tiên (thay đổi theo các ngày CUTOFF):

# %%
com_t = com_table
com_t['Date_On_Set'] = pd.to_datetime(com_t['CUTOFF'].str[:4]+"-"+com_t['CUTOFF'].str[4:6]+"-"+com_t['CUTOFF'].str[6:])
if ('20230531' in com_t['CUTOFF'].values):
    com_t.loc[:,'Start_Month'] = '2023-04-30'
elif ('20220228' in com_t['CUTOFF'].values):
    com_t.loc[:,'Start_Month'] = '2022-01-28'
elif ('20220429' in com_t['CUTOFF'].values):
    com_t.loc[:,'Start_Month'] = '2022-03-31'
elif ('20220531' in com_t['CUTOFF'].values):
    com_t.loc[:,'Start_Month'] = '2022-04-30' 
elif ('20240229' in com_t['CUTOFF'].values):
    com_t.loc[:,'Start_Month'] = '2024-01-27'
else: 
    com_t['Start_Month'] = (com_t['Date_On_Set'].dt.floor('d') + pd.offsets.MonthEnd(0) - pd.offsets.MonthBegin(1))
com_t
#Lấy kỳ xét và loại ra các trạng thái HD hủy, chưa pass 21 ngày FL
com_t = com_t[(com_t['Freelook'] >21)]
com_t = com_t[~com_t['Policy Status'].isin(['CF', 'DC', 'FL', 'NT', 'WD', 'PO', 'SU', 'TR'])]
com_t
# Out:
#         Policy No Product Code Premium transaction  \
# 0        80000047         EC01                B522
# 1        80000047         RAC2                B522
# 2        80000047         EC01                B522
# 3        80000047         EC01                B522
# 4        80000047         RAC2                B522
# ...           ...          ...                 ...
# 1262556  80131422         RHB1                T642
# 1262557  80131423         UL05                T642
# 1262558  80131424         UL05                T642
# 1262559  80131425         UL05                T642
# 1264272  80130999         URW5                T642
#
#                Premium transaction name  Premium Collected Collected Date  \
# 0        Premium Collection                      3002000.0     2018-07-13
# 1        Premium Collection                       360000.0     2019-06-25
# 2        Premium Collection                      3002000.0     2019-06-25
# 3        Premium Collection                      3002000.0     2020-06-22
# 4        Premium Collection                       360000.0     2020-06-22
# ...                                 ...                ...            ...
# 1262556  Contract Issue                           244000.0     2022-12-31
# 1262557  Contract Issue                         12750000.0     2023-01-04
# 1262558  Contract Issue                         12000000.0     2023-01-03
# 1262559  Contract Issue                          4526000.0     2022-12-31
# 1264272  Contract Issue                          1180000.0     2022-12-30
#
#         Applied Premium Date        FYC       RYC  Shared Commission Rate  \
# 0                 2018-07-13        0.0  150000.0                   100.0
# 1                 2019-06-25        0.0   11000.0                   100.0
# 2                 2019-06-25        0.0   60000.0                   100.0
# 3                 2020-06-22        0.0   60000.0                   100.0
# 4                 2020-06-22        0.0   11000.0                   100.0
# ...                      ...        ...       ...                     ...
# 1262556           2022-12-31    37000.0       0.0                   100.0
# 1262557           2023-01-04  4590000.0       0.0                   100.0
# 1262558           2023-01-03  4320000.0       0.0                   100.0
# 1262559           2022-12-31  1629000.0       0.0                   100.0
# 1264272           2022-12-30   413000.0       0.0                   100.0
#
#          ... Transfer Date  Proposal Receive Date Freelook RISK_COMMENCE_DATE  \
# 0        ...    2017-03-24             2014-06-19   3144.0         2014-06-19
# 1        ...    2017-03-24             2014-06-19   3144.0         2014-06-19
# 2        ...    2017-03-24             2014-06-19   3144.0         2014-06-19
# 3        ...    2020-01-07             2014-06-19   3144.0         2014-06-19
# 4        ...    2020-01-07             2014-06-19   3144.0         2014-06-19
# ...      ...           ...                    ...      ...                ...
# 1262556  ...    2022-12-31             2022-12-31     22.0         2022-12-31
# 1262557  ...    2022-12-31             2022-12-31     22.0         2022-12-31
# 1262558  ...    2022-12-31             2022-12-31     22.0         2022-12-31
# 1262559  ...    2022-12-31             2022-12-31     22.0         2022-12-31
# 1264272  ...    2022-12-30             2022-12-30     24.0         2022-12-30
#
#         Receive Policy date Premium Year    CUTOFF RETURN_DATE Date_On_Set  \
# 0                2014-06-24            5  20230131        None  2023-01-31
# 1                2014-06-24            6  20230131        None  2023-01-31
# 2                2014-06-24            6  20230131        None  2023-01-31
# 3                2014-06-24            7  20230131        None  2023-01-31
# 4                2014-06-24            7  20230131        None  2023-01-31
# ...                     ...          ...       ...         ...         ...
# 1262556          2023-01-10            1  20230131        None  2023-01-31
# 1262557          2023-01-10            1  20230131        None  2023-01-31
# 1262558          2023-01-10            1  20230131        None  2023-01-31
# 1262559          2023-01-10            1  20230131        None  2023-01-31
# 1264272          2023-01-08            1  20230131        None  2023-01-31
#
#         Start_Month
# 0        2023-01-01
# 1        2023-01-01
# 2        2023-01-01
# 3        2023-01-01
# 4        2023-01-01
# ...             ...
# 1262556  2023-01-01
# 1262557  2023-01-01
# 1262558  2023-01-01
# 1262559  2023-01-01
# 1264272  2023-01-01
#
# [1191281 rows x 33 columns]

# %% [markdown]
# <h5>3.2 Tính hoa hồng theo hợp đồng

# %%
#Cộng thêm 21 ngày ACK để có kỳ xét hoa hồng chính thức
cal_com = com_t
cal_com['Valid_Date'] = np.where(cal_com['Receive Policy date'] >= cal_com['Applied Premium Date'], cal_com['Receive Policy date'], cal_com['Applied Premium Date'])
cal_com['Valid_Date'] = cal_com['Valid_Date'] + timedelta(days=22) #+22 để bảo đảm qua được 21 ngày cân nhắc
cal_com = cal_com[(cal_com['Valid_Date'] >= cal_com['Start_Month']) & (cal_com['Valid_Date'] <= cal_com['Date_On_Set'])
        & cal_com['FYC'] != 0]
cal_com = cal_com.groupby(['Commission Agent','Policy No', 'Issued Date', 'Applied Premium Date', 'Receive Policy date', 'Freelook'], dropna=False)[['FYC', 'Premium Collected']].sum().reset_index()
cal_com
# Out:
#      Commission Agent Policy No Issued Date Applied Premium Date  \
# 0            60000482  80129181  2022-12-21           2022-12-21
# 1            60000717  80130920  2022-12-30           2022-12-30
# 2            60000727  80129635  2022-12-26           2022-12-26
# 3            60000727  80130411  2022-12-29           2022-12-29
# 4            60000823  80126877  2022-11-30           2022-11-30
# ...               ...       ...         ...                  ...
# 4025         60075723  80131251  2022-12-31           2022-12-31
# 4026         60075741  80131401  2022-12-31           2022-12-31
# 4027         60075745  80131450  2023-01-03           2023-01-03
# 4028         60075745  80131476  2023-01-04           2023-01-04
# 4029         60075750  80131256  2022-12-31           2022-12-31
#
#      Receive Policy date  Freelook         FYC  Premium Collected
# 0             2022-12-25      38.0   7340000.0         21260000.0
# 1             2023-01-07      25.0   7473000.0         21925000.0
# 2             2023-01-03      29.0   7500000.0         21638000.0
# 3             2023-01-04      28.0   8619000.0         25047000.0
# 4             2022-12-13      50.0   4122000.0         12424000.0
# ...                  ...       ...         ...                ...
# 4025          2023-01-09      23.0   1597000.0          4501000.0
# 4026          2023-01-09      23.0   4328000.0         12023000.0
# 4027          2023-01-09      23.0  11188000.0         29973000.0
# 4028          2023-01-09      23.0   7992000.0         20546000.0
# 4029          2023-01-09      23.0   1610000.0          4555000.0
#
# [4030 rows x 8 columns]

# %% [markdown]
# <h3> 4. Ghép lại thông tin

# %%
agent_com = pd.merge(introducee_info, cal_com, left_on = 'Introducee', right_on ='Commission Agent', how ='left')
agent_com = agent_com[agent_com['Commission Agent'].notnull()]
agent_com
# Out:
#       Introducer           IntroducerName IntroducerGrade IntroducerStatus  \
# 48      60055932        NGUYỄN QUỐC HUY              DM          Enforce
# 49      60055932        NGUYỄN QUỐC HUY              DM          Enforce
# 50      60055932        NGUYỄN QUỐC HUY              DM          Enforce
# 94      60035181        VÕ THỊ XUÂN HOA              FM          Enforce
# 115     60070705        LÊ TRƯỜNG KHÁNH              FC          Enforce
# ...          ...                      ...             ...              ...
# 55465   60072364    VÕ THỊ MỘNG TUYỀN              FM          Enforce
# 55485   60055379          CAO TIẾN CƯƠNG              FM          Enforce
# 55495   60058378  NGUYỄN THỊ THANH LOAN              FM          Enforce
# 55500   60071078         HOÀNG MẠNH SƠN              FM          Enforce
# 55501   60071078         HOÀNG MẠNH SƠN              FM          Enforce
#
#       IntroducerAppointed Introducee           IntroduceeName IntroduceeGrade  \
# 48             2022-01-22   60055933      NGUYỄN THÀNH CÔNG              DM
# 49             2022-01-22   60055933      NGUYỄN THÀNH CÔNG              DM
# 50             2022-01-22   60055933      NGUYỄN THÀNH CÔNG              DM
# 94             2020-12-24   60070966          NGUYỄN VĂN TỰ              FC
# 115            2022-10-19   60072004      LÊ NGUYỄN UYÊN NHI              FC
# ...                   ...        ...                      ...             ...
# 55465          2022-11-14   60072045        NGUYỄN VĂN QUANG              FC
# 55485          2022-01-04   60069834    PHẠM HOÀNG XUÂN MAI              FC
# 55495          2022-12-07   60058383  NGUYỄN THỊ NGỌC ÁNH              FC
# 55500          2023-01-17   60071704        HOÀNG DIỆU LINH              FC
# 55501          2023-01-17   60071704        HOÀNG DIỆU LINH              FC
#
#       IntroduceeStatus IntroduceeAppointed  ...    CUTOFF  \
# 48             Enforce          2022-01-22  ...  20230131
# 49             Enforce          2022-01-22  ...  20230131
# 50             Enforce          2022-01-22  ...  20230131
# 94             Enforce          2022-10-20  ...  20230131
# 115            Enforce          2022-11-11  ...  20230131
# ...                ...                 ...  ...       ...
# 55465          Enforce          2022-11-15  ...  20230131
# 55485          Enforce          2022-09-26  ...  20230131
# 55495          Enforce          2022-04-23  ...  20230131
# 55500          Enforce          2022-10-29  ...  20230131
# 55501          Enforce          2022-10-29  ...  20230131
#
#       Length of Service(Months) Commission Agent Policy No  Issued Date  \
# 48                           12         60055933  80128656   2022-12-16
# 49                           12         60055933  80128658   2022-12-16
# 50                           12         60055933  80128667   2022-12-16
# 94                            3         60070966  80122852   2022-10-20
# 115                           2         60072004  80129467   2022-12-23
# ...                         ...              ...       ...          ...
# 55465                         2         60072045  80129530   2022-12-23
# 55485                         4         60069834  80130856   2022-12-30
# 55495                         9         60058383  80112464   2022-06-23
# 55500                         3         60071704  80127041   2022-11-30
# 55501                         3         60071704  80131095   2022-12-31
#
#       Applied Premium Date Receive Policy date Freelook         FYC  \
# 48              2022-12-16          2022-12-21     42.0   7060000.0
# 49              2022-12-16          2022-12-21     42.0   7156000.0
# 50              2022-12-16          2022-12-21     42.0  11136000.0
# 94              2022-12-27          2022-10-26     98.0   1472000.0
# 115             2022-12-23          2022-12-28     35.0  14448000.0
# ...                    ...                 ...      ...         ...
# 55465           2022-12-23          2022-12-29     34.0   4304000.0
# 55485           2022-12-30          2023-01-09     23.0   1712000.0
# 55495           2022-12-29          2022-07-04    212.0   5211000.0
# 55500           2022-11-30          2022-12-10     53.0  14462000.0
# 55501           2022-12-31          2023-01-09     23.0   5471000.0
#
#       Premium Collected
# 48           18086000.0
# 49           18016000.0
# 50           30007000.0
# 94            4205000.0
# 115          41314000.0
# ...                 ...
# 55465        12003000.0
# 55485         4504000.0
# 55495        13995000.0
# 55500        40319000.0
# 55501        15242000.0
#
# [3789 rows x 23 columns]

# %%
agent_com.to_csv('checkcom.csv', encoding = 'utf-8-sig')

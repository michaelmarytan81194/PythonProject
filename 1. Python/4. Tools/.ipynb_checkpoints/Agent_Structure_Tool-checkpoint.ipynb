# %%
import pandas as pd

# %%
#Create connection to SQL Server
import sqlalchemy as sa
connection_uri = (
    "mssql+pyodbc://TEDPHO0134\TANDT_DP/DP_Tan?driver=ODBC+Driver+17+for+SQL+Server"
)
conn = sa.create_engine(connection_uri)

# %%
cutoff = '20240126'

# %%
query_statement = f"select * from AGENT_INFO where CUTOFF = {cutoff}"
agent_info = pd.read_sql(query_statement, conn)
agent_info.head(10)
# Out:
#   Area_Name                     Sales_Unit Sales_Unit_Code  \
# 0       DR1              Lưu Hoàng Thiện           AD018
# 1       DR1  Nguyễn Thị Thanh Loan (TER)           AD049
# 2       HLO                   Not Assigned           ADNUL
# 3       HLO                   Not Assigned           ADNUL
# 4       DR1         Đinh Hoàng Minh Diễm           AD013
# 5       DR1        Nguyễn Hải Yến (DR1)           AD036
# 6       DR1      Nguyễn Thị Thanh Tuyền           AD052
# 7       HLO                   Not Assigned           ADNUL
# 8       HLO                   Not Assigned           ADNUL
# 9       HN1                   Not Assigned           ADNUL
#
#   Parent_Supervisor_Code Parent_Supervisor_Name Supervisor_Code  \
# 0                   None                   None
# 1                   None                   None
# 2                                          None        60013747
# 3                                          None        60015473
# 4                   None                   None
# 5                   None                   None
# 6                   None                   None
# 7                                          None        60013747
# 8               60015473     FM - VŨ THỊ THÀ        60019724
# 9                                          None        60012707
#
#             Supervisor_Name Agent_Number                      Agent_Name  \
# 0                      None     69999988  Bảo hiểm nhân thọ Phú Hưng
# 1                      None     69999966  Bảo hiểm nhân thọ Phú Hưng
# 2       FM - ĐẶNG LONG TÂN     60016738               NGUYỄN VĂN HIỀN
# 3        FM - VŨ THỊ THÀ     60019723                    LÊ VĂN HIỀN
# 4                      None     69999994  Bảo hiểm nhân thọ Phú Hưng
# 5                      None     69999987  Bảo hiểm nhân thọ Phú Hưng
# 6                      None     69999969  Bảo hiểm nhân thọ Phú Hưng
# 7       FM - ĐẶNG LONG TÂN     60014363                  VŨ THỊ HOÀI
# 8     FM - PHẠM THỊ QUYÊN     60019844                NGUYỄN THỊ LEN
# 9  FM - ĐINH THỊ THU THANH     60012715              LƯU THỊ THU HƯƠNG
#
#    Gender  ...    Leader SFC Leader_count Appointed_TAPSU    CUTOFF  \
# 0    Male  ...      None                0      2014-10-15  20240126
# 1  Female  ...      None                0      2015-10-29  20240126
# 2    Male  ...  60013747                1      2018-09-20  20240126
# 3    Male  ...      None                1      2019-03-01  20240126
# 4  Female  ...      None                0      2014-08-12  20240126
# 5  Female  ...      None                0      2014-10-16  20240126
# 6  Female  ...      None                0      2015-11-05  20240126
# 7  Female  ...      None                1      2018-05-23  20240126
# 8  Female  ...  60019724                2      2019-03-01  20240126
# 9  Female  ...  60012707                1      2018-01-24  20240126
#
#   First_Appointed                       Area_Desc TERRITORY HOT Name  \
# 0      2014-10-15  Direct Sales                        None     None
# 1      2015-10-29  Direct Sales                        None     None
# 2      2018-09-20  Ha Long                             None     None
# 3      2019-03-01  Ha Long                             None     None
# 4      2014-08-12  Direct Sales                        None     None
# 5      2014-10-16  Direct Sales                        None     None
# 6      2015-11-05  Direct Sales                        None     None
# 7      2018-05-23  Ha Long                             None     None
# 8      2019-03-01  Ha Long                             None     None
# 9      2018-01-24  Ha Noi                              None     None
#
#    Sale_Unit_Grade
# 0             None
# 1             None
# 2             None
# 3             None
# 4             None
# 5             None
# 6             None
# 7             None
# 8             None
# 9             None
#
# [10 rows x 70 columns]

# %%
agent_info.columns #check columns of DF
# Out:
# Index(['Area_Name', 'Sales_Unit', 'Sales_Unit_Code', 'Parent_Supervisor_Code',
#        'Parent_Supervisor_Name', 'Supervisor_Code', 'Supervisor_Name',
#        'Agent_Number', 'Agent_Name', 'Gender', 'Grade', 'Club_Class',
#        'Agent_Status', 'Birthday', 'BirthPlace', 'ID_Card', 'Issued Date',
#        'Issued Place', 'Marriage', 'Age', 'Client_Code', 'Client_Name',
#        'Email', 'Telephone', 'Hand_Phone', 'Contact Address', 'Contact2',
#        'Contact3', 'Contact4', 'Contact5', 'Alternate_Address', 'Alternate2',
#        'Alternate3', 'Alternate4', 'Alternate5', 'Date_Appointed',
#        'Terminated_date', 'Reason Terminated', 'Recovered Date',
#        'Client Number of Introducer', 'Client Name of Introducer',
#        'Client ID number of Introducer', 'Agent Numer of Introducer',
#        'Agent_Bank_Account', 'Bank_Code', 'Bank Name', 'Bank_Address',
#        'Bank_Address2', 'Bank_Address3', 'Bank_Address4', 'License_No',
#        'Tax Code', 'Tax Office', 'Previous Insurance',
#        'Experience in the insurance', 'Agent Classification', 'Promote_Date',
#        'Demote_Date', 'Effective_Date_Club_Class', 'Bank_Number', 'Leader',
#        'SFC', 'Leader_count', 'Appointed_TAPSU', 'CUTOFF', 'First_Appointed',
#        'Area_Desc', 'TERRITORY', 'HOT Name', 'Sale_Unit_Grade'],
#       dtype='object')

# %%
#Make Parent table
parent = agent_info[['Parent_Supervisor_Code', 'Parent_Supervisor_Name', 'Agent_Number', 'Agent_Name', 'Grade', 'CUTOFF']]
parent = parent[parent['Parent_Supervisor_Code'].notnull() & parent['Parent_Supervisor_Name'].notnull()]
parent.insert(0, "Mark_Level", "B", True) #ADD a new columm named Mark_Level
parent = parent.rename(columns={"Parent_Supervisor_Code": "HigherCode", "Parent_Supervisor_Name":"HigherName"})
parent
# Out:
#       Mark_Level HigherCode             HigherName Agent_Number  \
# 8              B   60015473     FM - VŨ THỊ THÀ     60019844
# 10             B   60015473     FM - VŨ THỊ THÀ     60018161
# 12             B   60013747    FM - ĐẶNG LONG TÂN     60015151
# 18             B   60015473     FM - VŨ THỊ THÀ     60018162
# 20             B   60013747    FM - ĐẶNG LONG TÂN     60018160
# ...          ...        ...                    ...          ...
# 82830          B   60001562    FC - ĐẶNG VĂN SUNG     60001756
# 82831          B   60001562    FC - ĐẶNG VĂN SUNG     60002674
# 82832          B   60007038     DM - HỒ VĂN KHIÊM     60002431
# 82833          B   60007038     DM - HỒ VĂN KHIÊM     60002433
# 82845          B   60006494  DM - ĐINH THỊ NGUYÊN     60012465
#
#                   Agent_Name Grade    CUTOFF
# 8           NGUYỄN THỊ LEN    FC  20240126
# 10         VƯƠNG THỊ NHÁNH    FC  20240126
# 12        NGUYỄN KHẮC MÙA    FC  20240126
# 18            PHẠM THỊ LÂM    FC  20240126
# 20            NGÔ PHƯƠNG MAI    FC  20240126
# ...                      ...   ...       ...
# 82830      NGUYỄN THỊ THƠM    AM  20240126
# 82831       HUỲNH THANH TÂM    FC  20240126
# 82832     PHAN THỊ KIM YẾN    FC  20240126
# 82833  TRƯƠNG THỊ NGỌC NGA    FC  20240126
# 82845    NGUYỄN THỊ HƯỜNG    FC  20240126
#
# [39532 rows x 7 columns]

# %%
sup = agent_info[['Supervisor_Code', 'Supervisor_Name', 'Agent_Number', 'Agent_Name', 'Grade', 'CUTOFF']]
sup = sup[sup['Supervisor_Code'].notnull() & sup['Supervisor_Name'].notnull()]
sup.insert(0, "Mark_Level", "A", True)
sup = sup.rename(columns={"Supervisor_Code": "HigherCode", "Supervisor_Name":"HigherName"})
sup
# Out:
#       Mark_Level HigherCode                HigherName Agent_Number  \
# 2              A   60013747       FM - ĐẶNG LONG TÂN     60016738
# 3              A   60015473        FM - VŨ THỊ THÀ     60019723
# 7              A   60013747       FM - ĐẶNG LONG TÂN     60014363
# 8              A   60019724     FM - PHẠM THỊ QUYÊN     60019844
# 9              A   60012707  FM - ĐINH THỊ THU THANH     60012715
# ...          ...        ...                       ...          ...
# 82841          A   60012728       FC - VŨ THỊ CHUNG     60015914
# 82842          A   60013120         FC - ĐÀO ANH TÚ     60018135
# 82843          A   60013383          DM - DUMMY 13383     60013527
# 82844          A   60019183  FC - LÊ THỊ NGỌC HƯƠNG     60019184
# 82845          A   60010702        FC - CAO THỊ CÚC     60012465
#
#                         Agent_Name Grade    CUTOFF
# 2                NGUYỄN VĂN HIỀN    FC  20240126
# 3                     LÊ VĂN HIỀN    FM  20240126
# 7                   VŨ THỊ HOÀI    FM  20240126
# 8                 NGUYỄN THỊ LEN    FC  20240126
# 9               LƯU THỊ THU HƯƠNG    FC  20240126
# ...                            ...   ...       ...
# 82841          NGUYỄN ĐÌNH HOÀN    FC  20240126
# 82842  PHAN NGUYỄN LÊ THIÊN HƯƠNG    FC  20240126
# 82843                  ĐIỂU KHƯƠI    FC  20240126
# 82844     TRẦN THỊ BÍCH PHƯỢNG    FC  20240126
# 82845          NGUYỄN THỊ HƯỜNG    FC  20240126
#
# [68721 rows x 7 columns]

# %%
parent_sup = pd.concat([parent, sup]) #this is like UNION in SQL
parent_sup['rank'] = parent_sup.groupby('Agent_Number')['Mark_Level'].rank(method='dense', ascending=True)
parent_sup #Group by Agent Number and rank by Mark_Level
# Out:
#       Mark_Level HigherCode                HigherName Agent_Number  \
# 8              B   60015473        FM - VŨ THỊ THÀ     60019844
# 10             B   60015473        FM - VŨ THỊ THÀ     60018161
# 12             B   60013747       FM - ĐẶNG LONG TÂN     60015151
# 18             B   60015473        FM - VŨ THỊ THÀ     60018162
# 20             B   60013747       FM - ĐẶNG LONG TÂN     60018160
# ...          ...        ...                       ...          ...
# 82841          A   60012728       FC - VŨ THỊ CHUNG     60015914
# 82842          A   60013120         FC - ĐÀO ANH TÚ     60018135
# 82843          A   60013383          DM - DUMMY 13383     60013527
# 82844          A   60019183  FC - LÊ THỊ NGỌC HƯƠNG     60019184
# 82845          A   60010702        FC - CAO THỊ CÚC     60012465
#
#                         Agent_Name Grade    CUTOFF  rank
# 8                 NGUYỄN THỊ LEN    FC  20240126   2.0
# 10               VƯƠNG THỊ NHÁNH    FC  20240126   2.0
# 12              NGUYỄN KHẮC MÙA    FC  20240126   2.0
# 18                  PHẠM THỊ LÂM    FC  20240126   2.0
# 20                  NGÔ PHƯƠNG MAI    FC  20240126   2.0
# ...                            ...   ...       ...   ...
# 82841          NGUYỄN ĐÌNH HOÀN    FC  20240126   1.0
# 82842  PHAN NGUYỄN LÊ THIÊN HƯƠNG    FC  20240126   1.0
# 82843                  ĐIỂU KHƯƠI    FC  20240126   1.0
# 82844     TRẦN THỊ BÍCH PHƯỢNG    FC  20240126   1.0
# 82845          NGUYỄN THỊ HƯỜNG    FC  20240126   1.0
#
# [108253 rows x 8 columns]

# %%
#Take the rank = 1 as Priority
parent_sup = parent_sup[parent_sup['rank'] == 1]
parent_sup = parent_sup[['HigherCode','HigherName','Agent_Number','Agent_Name','Grade', 'CUTOFF']]
parent_sup.insert(2, "HigherGrade", parent_sup['HigherName'].str[:2], True)
parent_sup.insert(2, "Higher Name", parent_sup['HigherName'].str.split('-').str[1] , True)
#parent_sup['HigherName'].str.split('-') is a list, then take a 2nd Item as name
parent_sup = parent_sup[['CUTOFF','Agent_Number','Agent_Name','Grade', 'HigherCode','Higher Name','HigherGrade']].rename(columns={"Higher Name":"HigherName"})
parent_sup_short = parent_sup[['HigherCode','HigherName','HigherGrade','Agent_Number']]
parent_sup_short
# Out:
#       HigherCode            HigherName HigherGrade Agent_Number
# 2       60013747        ĐẶNG LONG TÂN          FM     60016738
# 3       60015473         VŨ THỊ THÀ          FM     60019723
# 7       60013747        ĐẶNG LONG TÂN          FM     60014363
# 8       60019724      PHẠM THỊ QUYÊN          FM     60019844
# 9       60012707   ĐINH THỊ THU THANH          FM     60012715
# ...          ...                   ...         ...          ...
# 82841   60012728        VŨ THỊ CHUNG          FC     60015914
# 82842   60013120          ĐÀO ANH TÚ          FC     60018135
# 82843   60013383           DUMMY 13383          DM     60013527
# 82844   60019183   LÊ THỊ NGỌC HƯƠNG          FC     60019184
# 82845   60010702         CAO THỊ CÚC          FC     60012465
#
# [68721 rows x 4 columns]

# %% [markdown]
# <h4> Level 1 <h4>

# %%
level_1 = parent_sup.rename(columns={
                                    "Agent_Number":"AgentNumber", "Agent_Name":"AgentName", "Grade":"AgentGrade",
                                    'HigherCode':"L1Code", "HigherName":"L1Name", "HigherGrade":"L1Grade"
                                    })
level_1
# Out:
#          CUTOFF AgentNumber                    AgentName AgentGrade    L1Code  \
# 2      20240126    60016738            NGUYỄN VĂN HIỀN         FC  60013747
# 3      20240126    60019723                 LÊ VĂN HIỀN         FM  60015473
# 7      20240126    60014363               VŨ THỊ HOÀI         FM  60013747
# 8      20240126    60019844             NGUYỄN THỊ LEN         FC  60019724
# 9      20240126    60012715           LƯU THỊ THU HƯƠNG         FC  60012707
# ...         ...         ...                          ...        ...       ...
# 82841  20240126    60015914          NGUYỄN ĐÌNH HOÀN         FC  60012728
# 82842  20240126    60018135  PHAN NGUYỄN LÊ THIÊN HƯƠNG         FC  60013120
# 82843  20240126    60013527                  ĐIỂU KHƯƠI         FC  60013383
# 82844  20240126    60019184     TRẦN THỊ BÍCH PHƯỢNG         FC  60019183
# 82845  20240126    60012465          NGUYỄN THỊ HƯỜNG         FC  60010702
#
#                      L1Name L1Grade
# 2            ĐẶNG LONG TÂN      FM
# 3             VŨ THỊ THÀ      FM
# 7            ĐẶNG LONG TÂN      FM
# 8          PHẠM THỊ QUYÊN      FM
# 9       ĐINH THỊ THU THANH      FM
# ...                     ...     ...
# 82841        VŨ THỊ CHUNG      FC
# 82842          ĐÀO ANH TÚ      FC
# 82843           DUMMY 13383      DM
# 82844   LÊ THỊ NGỌC HƯƠNG      FC
# 82845         CAO THỊ CÚC      FC
#
# [68721 rows x 7 columns]

# %%
level_2 = pd.merge(level_1, parent_sup_short, left_on = 'L1Code', right_on = 'Agent_Number', how = 'left')
#LEFT JOIN 
level_2 = level_2.loc[:,level_2.columns != 'Agent_Number'].rename(columns={'HigherCode':"L2Code",
                                                        "HigherName":"L2Name", "HigherGrade":"L2Grade", "CUTOFF_x": "CUTOFF"})
#level_2.loc[:,level_2.columns != 'Agent_Number'] => SELECT ALL COLUMNS, EXCEPT Agent_Number
level_2.head(10)
# Out:
#      CUTOFF AgentNumber           AgentName AgentGrade    L1Code  \
# 0  20240126    60016738   NGUYỄN VĂN HIỀN         FC  60013747
# 1  20240126    60019723        LÊ VĂN HIỀN         FM  60015473
# 2  20240126    60014363      VŨ THỊ HOÀI         FM  60013747
# 3  20240126    60019844    NGUYỄN THỊ LEN         FC  60019724
# 4  20240126    60012715  LƯU THỊ THU HƯƠNG         FC  60012707
# 5  20240126    60018161   VƯƠNG THỊ NHÁNH         FC  60018152
# 6  20240126    60015151  NGUYỄN KHẮC MÙA         FC  60013750
# 7  20240126    60013756        VŨ THỊ HÀ         FM  60013747
# 8  20240126    60018162      PHẠM THỊ LÂM         FC  60018152
# 9  20240126    60011416   NGUYỄN HỒNG VÂN         FC  60011415
#
#                   L1Name L1Grade    L2Code           L2Name L2Grade
# 0         ĐẶNG LONG TÂN      FM       NaN              NaN     NaN
# 1          VŨ THỊ THÀ      FM       NaN              NaN     NaN
# 2         ĐẶNG LONG TÂN      FM       NaN              NaN     NaN
# 3       PHẠM THỊ QUYÊN      FM  60015473    VŨ THỊ THÀ      FM
# 4    ĐINH THỊ THU THANH      FM       NaN              NaN     NaN
# 5     NGUYỄN THỊ LƯƠNG      FM  60015473    VŨ THỊ THÀ      FM
# 6         VŨ THỊ THẢO      FM  60013747   ĐẶNG LONG TÂN      FM
# 7         ĐẶNG LONG TÂN      FM       NaN              NaN     NaN
# 8     NGUYỄN THỊ LƯƠNG      FM  60015473    VŨ THỊ THÀ      FM
# 9   PHAN THỊ TIẾN HUỆ      FM       NaN              NaN     NaN

# %%
level_3 = pd.merge(level_2, parent_sup_short, left_on = 'L2Code', right_on = 'Agent_Number', how = 'left')
level_3 = level_3.loc[:,level_3.columns != 'Agent_Number'].rename(columns={'HigherCode':"L3Code",
                                                        "HigherName":"L3Name", "HigherGrade":"L3Grade", "CUTOFF_x": "CUTOFF"})
level_3.sort_values('L3Code') 
#In order to check if the Highest Level is still, need to sort_values
# Out:
#          CUTOFF AgentNumber                    AgentName AgentGrade    L1Code  \
# 41061  20240126    60000651            TRẦN THANH HƯƠNG         AM  60000377
# 36203  20240126    60000786              PHÙNG MINH SƠN         AM  60000377
# 36227  20240126    60000302         LÊ DIỆP THANH TRÚC         FC  60000446
# 38407  20240126    60000416                  HÀ DUY TÂM         FC  60000300
# 39865  20240126    60000448            TRẦN CÔNG CHÍNH         FC  60000447
# ...         ...         ...                          ...        ...       ...
# 68716  20240126    60015914          NGUYỄN ĐÌNH HOÀN         FC  60012728
# 68717  20240126    60018135  PHAN NGUYỄN LÊ THIÊN HƯƠNG         FC  60013120
# 68718  20240126    60013527                  ĐIỂU KHƯƠI         FC  60013383
# 68719  20240126    60019184     TRẦN THỊ BÍCH PHƯỢNG         FC  60019183
# 68720  20240126    60012465          NGUYỄN THỊ HƯỜNG         FC  60010702
#
#                      L1Name L1Grade    L2Code                 L2Name L2Grade  \
# 41061     LÊ THỊ THU TRANG      AM  60000199   PHẠM THỊ THU HỒNG      AM
# 36203     LÊ THỊ THU TRANG      AM  60000199   PHẠM THỊ THU HỒNG      AM
# 36227     NGUYỄN KHÁNH LY      AM  60000199   PHẠM THỊ THU HỒNG      AM
# 38407           CAO THỊ AN      AM  60000201         CAO BIÊN CƯƠNG      AM
# 39865     TRẦN THỊ THÀNH      AM  60000202           LÊ MỌNG LÂM      AM
# ...                     ...     ...       ...                    ...     ...
# 68716        VŨ THỊ CHUNG      FC       NaN                    NaN     NaN
# 68717          ĐÀO ANH TÚ      FC       NaN                    NaN     NaN
# 68718           DUMMY 13383      DM       NaN                    NaN     NaN
# 68719   LÊ THỊ NGỌC HƯƠNG      FC       NaN                    NaN     NaN
# 68720         CAO THỊ CÚC      FC  60006494       ĐINH THỊ NGUYÊN      DM
#
#          L3Code                   L3Name L3Grade
# 41061  60000176   PHẠM KIỀU THỦY TIÊN      FM
# 36203  60000176   PHẠM KIỀU THỦY TIÊN      FM
# 36227  60000176   PHẠM KIỀU THỦY TIÊN      FM
# 38407  60000176   PHẠM KIỀU THỦY TIÊN      FM
# 39865  60000176   PHẠM KIỀU THỦY TIÊN      FM
# ...         ...                      ...     ...
# 68716       NaN                      NaN     NaN
# 68717       NaN                      NaN     NaN
# 68718       NaN                      NaN     NaN
# 68719       NaN                      NaN     NaN
# 68720       NaN                      NaN     NaN
#
# [68721 rows x 13 columns]

# %%
level_4 = pd.merge(level_3, parent_sup_short, left_on = 'L3Code', right_on = 'Agent_Number', how = 'left')
level_4 = level_4.loc[:,level_4.columns != 'Agent_Number'].rename(columns={'HigherCode':"L4Code",
                                                        "HigherName":"L4Name", "HigherGrade":"L4Grade", "CUTOFF_x": "CUTOFF"})
level_4.sort_values('L4Code')
# Out:
#          CUTOFF AgentNumber                    AgentName AgentGrade    L1Code  \
# 35803  20240126    60000545           NGUYỄN THỊ THÁI         FC  60000786
# 34061  20240126    60000778         PHẠM THỊ THU THẢO         FC  60000764
# 45873  20240126    60000777           VÕ THỊ KIM QUYÊN         FC  60000764
# 628    20240126    60000097       NGUYỄN THỊ THU THẢO         FC  60000076
# 3579   20240126    60000098         NGUYỄN LÊ THANH TÂN         FC  60000076
# ...         ...         ...                          ...        ...       ...
# 68716  20240126    60015914          NGUYỄN ĐÌNH HOÀN         FC  60012728
# 68717  20240126    60018135  PHAN NGUYỄN LÊ THIÊN HƯƠNG         FC  60013120
# 68718  20240126    60013527                  ĐIỂU KHƯƠI         FC  60013383
# 68719  20240126    60019184     TRẦN THỊ BÍCH PHƯỢNG         FC  60019183
# 68720  20240126    60012465          NGUYỄN THỊ HƯỜNG         FC  60010702
#
#                      L1Name L1Grade    L2Code                L2Name L2Grade  \
# 35803       PHÙNG MINH SƠN      AM  60000377     LÊ THỊ THU TRANG      AM
# 34061      TRẦN THỊ THẢO      AM  60000447     TRẦN THỊ THÀNH      AM
# 45873      TRẦN THỊ THẢO      AM  60000447     TRẦN THỊ THÀNH      AM
# 628          ĐỖ VĂN ĐƯỜNG      FC  60000328   TÔ THỊ THANH THỦY      AM
# 3579         ĐỖ VĂN ĐƯỜNG      FC  60000328   TÔ THỊ THANH THỦY      AM
# ...                     ...     ...       ...                   ...     ...
# 68716        VŨ THỊ CHUNG      FC       NaN                   NaN     NaN
# 68717          ĐÀO ANH TÚ      FC       NaN                   NaN     NaN
# 68718           DUMMY 13383      DM       NaN                   NaN     NaN
# 68719   LÊ THỊ NGỌC HƯƠNG      FC       NaN                   NaN     NaN
# 68720         CAO THỊ CÚC      FC  60006494      ĐINH THỊ NGUYÊN      DM
#
#          L3Code                 L3Name L3Grade    L4Code  \
# 35803  60000199   PHẠM THỊ THU HỒNG      AM  60000176
# 34061  60000202           LÊ MỌNG LÂM      AM  60000176
# 45873  60000202           LÊ MỌNG LÂM      AM  60000176
# 628    60001426         NGÔ NGỌC CHÂU      AM  60000249
# 3579   60001426         NGÔ NGỌC CHÂU      AM  60000249
# ...         ...                    ...     ...       ...
# 68716       NaN                    NaN     NaN       NaN
# 68717       NaN                    NaN     NaN       NaN
# 68718       NaN                    NaN     NaN       NaN
# 68719       NaN                    NaN     NaN       NaN
# 68720       NaN                    NaN     NaN       NaN
#
#                         L4Name L4Grade
# 35803   PHẠM KIỀU THỦY TIÊN      FM
# 34061   PHẠM KIỀU THỦY TIÊN      FM
# 45873   PHẠM KIỀU THỦY TIÊN      FM
# 628      VÕ THỊ PHƯƠNG THẢO      FC
# 3579     VÕ THỊ PHƯƠNG THẢO      FC
# ...                        ...     ...
# 68716                      NaN     NaN
# 68717                      NaN     NaN
# 68718                      NaN     NaN
# 68719                      NaN     NaN
# 68720                      NaN     NaN
#
# [68721 rows x 16 columns]

# %%
level_5 = pd.merge(level_4, parent_sup_short, left_on = 'L4Code', right_on = 'Agent_Number', how = 'left')
level_5 = level_5.loc[:,level_5.columns != 'Agent_Number'].rename(columns={'HigherCode':"L5Code",
                                                        "HigherName":"L5Name", "HigherGrade":"L5Grade", "CUTOFF_x": "CUTOFF"})
level_5.sort_values('L5Code').head(5)
# Out:
#          CUTOFF AgentNumber           AgentName AgentGrade    L1Code  \
# 22317  20240126    60008989          TÔ VĂN HÂN         FC  60008059
# 22719  20240126    60008629         TÔ VĂN HUỆ         FC  60008059
# 21410  20240126    60060044      TRẦN THỊ LÝ         FC  60057650
# 17020  20240126    60008628  NGUYỄN THỊ XIỄM         FC  60008059
# 29118  20240126    60009438  VŨ THỊ MINH CHÂU         FC  60005670
#
#                          L1Name L1Grade    L2Code                   L2Name  \
# 22317   TRẦN THỊ BÍCH TUYỀN      FC  60024127        NGUYỄN HỮU VINH
# 22719   TRẦN THỊ BÍCH TUYỀN      FC  60024127        NGUYỄN HỮU VINH
# 21410        NGUYỄN THỊ TRANG      FC  60055404       TRẦN THỊ NHỦ EM
# 17020   TRẦN THỊ BÍCH TUYỀN      FC  60024127        NGUYỄN HỮU VINH
# 29118       NGUYỄN THÀNH VINH      AM  60004680   PHẠM THỤY QUỲNH NHƯ
#
#       L2Grade    L3Code                  L3Name L3Grade    L4Code  \
# 22317      FC  60000717   NGUYỄN THỊ KIM YẾN      FM  60001255
# 22719      FC  60000717   NGUYỄN THỊ KIM YẾN      FM  60001255
# 21410      FC  60055401      HUỲNH THỊ BÉ BA      FM  60001255
# 17020      FC  60000717   NGUYỄN THỊ KIM YẾN      FM  60001255
# 29118      FM  60006841           ĐỖ THÁI NAM      FC  60068331
#
#                     L4Name L4Grade    L5Code                     L5Name  \
# 22317   NGUYỄN HỒNG TƯƠI      FM  60000727   NGUYỄN THỊ NGỌC HIỀN
# 22719   NGUYỄN HỒNG TƯƠI      FM  60000727   NGUYỄN THỊ NGỌC HIỀN
# 21410   NGUYỄN HỒNG TƯƠI      FM  60000727   NGUYỄN THỊ NGỌC HIỀN
# 17020   NGUYỄN HỒNG TƯƠI      FM  60000727   NGUYỄN THỊ NGỌC HIỀN
# 29118     TẠ ĐÌNH PHƯƠNG      DM  60001463             LÊ BẢO KHÁNH
#
#       L5Grade
# 22317      FM
# 22719      FM
# 21410      FM
# 17020      FM
# 29118      DM

# %%
level_6 = pd.merge(level_5, parent_sup_short, left_on = 'L5Code', right_on = 'Agent_Number', how = 'left')
level_6 = level_6.loc[:,level_6.columns != 'Agent_Number'].rename(columns={'HigherCode':"L6Code",
                                                        "HigherName":"L6Name", "HigherGrade":"L6Grade", "CUTOFF_x": "CUTOFF"})
level_6.sort_values('L6Code').head(5)
# Out:
#          CUTOFF AgentNumber              AgentName AgentGrade    L1Code  \
# 29140  20240126    60011558       ĐOÀN THỊ CHÚC         FC  60011164
# 29141  20240126    60014463       DƯƠNG THỊ HIỀN         FC  60011164
# 35308  20240126    60013402       TRẦN VĂN HOÀNG         FC  60011164
# 31655  20240126    60022107       NGUYỄN THỊ BÉ         FC  60021883
# 41012  20240126    60022052  HUỲNH THỊ TRÚC LỆ         FC  60021883
#
#                      L1Name L1Grade    L2Code                   L2Name  \
# 29140         VÕ THỊ YẾN      FC  60045305   NGUYỄN THỊ KIM TRẦM
# 29141         VÕ THỊ YẾN      FC  60045305   NGUYỄN THỊ KIM TRẦM
# 35308         VÕ THỊ YẾN      FC  60045305   NGUYỄN THỊ KIM TRẦM
# 31655   NGUYỄN THANH TUẤN      FC  60008469   PHAN THỊ TUYẾT SƯƠNG
# 41012   NGUYỄN THANH TUẤN      FC  60008469   PHAN THỊ TUYẾT SƯƠNG
#
#       L2Grade  ... L3Grade    L4Code                 L4Name L4Grade    L5Code  \
# 29140      FC  ...      FC  60008948      LÊ THỊ NGỌC VĂN      FM  60066517
# 29141      FC  ...      FC  60008948      LÊ THỊ NGỌC VĂN      FM  60066517
# 35308      FC  ...      FC  60008948      LÊ THỊ NGỌC VĂN      FM  60066517
# 31655      FC  ...      FC  60068966   LÊ THỊ THÚY QUỲNH      FM  60066517
# 41012      FC  ...      FC  60068966   LÊ THỊ THÚY QUỲNH      FM  60066517
#
#                   L5Name L5Grade    L6Code              L6Name L6Grade
# 29140   TỐNG THANH LINH      DM  60008436   HUỲNH THỊ THÚY      DM
# 29141   TỐNG THANH LINH      DM  60008436   HUỲNH THỊ THÚY      DM
# 35308   TỐNG THANH LINH      DM  60008436   HUỲNH THỊ THÚY      DM
# 31655   TỐNG THANH LINH      DM  60008436   HUỲNH THỊ THÚY      DM
# 41012   TỐNG THANH LINH      DM  60008436   HUỲNH THỊ THÚY      DM
#
# [5 rows x 22 columns]

# %%
level_7 = pd.merge(level_6, parent_sup_short, left_on = 'L6Code', right_on = 'Agent_Number', how = 'left')
level_7 = level_7.loc[:,level_7.columns != 'Agent_Number'].rename(columns={'HigherCode':"L7Code",
                                                        "HigherName":"L7Name", "HigherGrade":"L7Grade", "CUTOFF_x": "CUTOFF"})
level_7.sort_values('L7Code').head(5)
# Out:
#          CUTOFF AgentNumber                     AgentName AgentGrade  \
# 27751  20240126    60082794         CHÂU THỊ THANH THÚY         FC
# 61050  20240126    60070821               HUỲNH VĂN TẤN         FC
# 61799  20240126    60061417                  LÊ VĂN TRUNG         FC
# 61795  20240126    60057600             NGUYỄN VĂN THANH         FC
# 63468  20240126    60056657  NGUYỄN THỊ THÙY TRANG VÂN         FC
#
#          L1Code                    L1Name L1Grade    L2Code  \
# 27751  60021565   NGUYỄN THỊ THANH LOAN      FC  60011164
# 61050  60067130   LƯƠNG THỊ PHƯƠNG THẢO      FC  60061019
# 61799  60061020         TẠ THỊ LỆ DUNG      FC  60061013
# 61795  60029659       NGUYỄN XUÂN PHÓNG      FC  60056655
# 63468  60056656            TẠ QUANG LỘC      FC  60056655
#
#                      L2Name L2Grade  ... L4Grade    L5Code  \
# 27751         VÕ THỊ YẾN      FC  ...      FC  60008948
# 61050   ĐỖ THỊ KIM PHỤNG      FM  ...      DM  60029413
# 61799     TRƯƠNG THỊ ĐIỆP      FM  ...      DM  60029413
# 61795         ĐÀO TIỂU MY      FM  ...      DM  60026501
# 63468         ĐÀO TIỂU MY      FM  ...      DM  60026501
#
#                         L5Name L5Grade    L6Code             L6Name L6Grade  \
# 27751        LÊ THỊ NGỌC VĂN      FM  60066517   TỐNG THANH LINH      DM
# 61050   NGUYỄN THỊ THÚY NGA      DM  60012256      LÊ VĂN TUYẾN      RM
# 61799   NGUYỄN THỊ THÚY NGA      DM  60012256      LÊ VĂN TUYẾN      RM
# 61795      ĐÀO THỊ UYỂN NHI      DM  60012256      LÊ VĂN TUYẾN      RM
# 63468      ĐÀO THỊ UYỂN NHI      DM  60012256      LÊ VĂN TUYẾN      RM
#
#          L7Code              L7Name L7Grade
# 27751  60008436   HUỲNH THỊ THÚY      DM
# 61050  60011794   LÊ THỊ THU HẰNG      GM
# 61799  60011794   LÊ THỊ THU HẰNG      GM
# 61795  60011794   LÊ THỊ THU HẰNG      GM
# 63468  60011794   LÊ THỊ THU HẰNG      GM
#
# [5 rows x 25 columns]

# %%
level_8 = pd.merge(level_7, parent_sup_short, left_on = 'L7Code', right_on = 'Agent_Number', how = 'left')
level_8 = level_8.loc[:,level_8.columns != 'Agent_Number'].rename(columns={'HigherCode':"L8Code",
                                                        "HigherName":"L8Name", "HigherGrade":"L8Grade", "CUTOFF_x": "CUTOFF"})
level_8.sort_values('L8Code').head(5)
# Out:
#          CUTOFF AgentNumber                 AgentName AgentGrade    L1Code  \
# 68527  20240126    60068583             LÊ VĂN TRỌNG         FC  60066896
# 61656  20240126    60052425               LÊ THỊ TỊ         FC  60052313
# 58522  20240126    60068550          NGUYỄN THỊ LAN         FC  60066896
# 58514  20240126    60056658           PHẠM THỊ THOA         FC  60056657
# 62510  20240126    60054379  PHẠM THỊ BÍCH PHƯỢNG         FC  60052425
#
#                               L1Name L1Grade    L2Code  \
# 68527     NGUYỄN HUỲNH THỊ THU MI      FC  60061020
# 61656         TRẦN THỊ THÙY TRANG      FC  60029659
# 58522     NGUYỄN HUỲNH THỊ THU MI      FC  60061020
# 58514   NGUYỄN THỊ THÙY TRANG VÂN      FC  60056656
# 62510                    LÊ THỊ TỊ      FC  60052313
#
#                         L2Name L2Grade  ... L5Grade    L6Code  \
# 68527        TẠ THỊ LỆ DUNG      FC  ...      DM  60029413
# 61656      NGUYỄN XUÂN PHÓNG      FC  ...      DM  60026501
# 58522        TẠ THỊ LỆ DUNG      FC  ...      DM  60029413
# 58514           TẠ QUANG LỘC      FC  ...      DM  60026501
# 62510   TRẦN THỊ THÙY TRANG      FC  ...      FM  60039893
#
#                         L6Name L6Grade    L7Code                L7Name  \
# 68527   NGUYỄN THỊ THÚY NGA      DM  60012256         LÊ VĂN TUYẾN
# 61656      ĐÀO THỊ UYỂN NHI      DM  60012256         LÊ VĂN TUYẾN
# 58522   NGUYỄN THỊ THÚY NGA      DM  60012256         LÊ VĂN TUYẾN
# 58514      ĐÀO THỊ UYỂN NHI      DM  60012256         LÊ VĂN TUYẾN
# 62510    BÙI THỊ BÍCH LIỄU      DM  60026501   ĐÀO THỊ UYỂN NHI
#
#       L7Grade    L8Code              L8Name L8Grade
# 68527      RM  60011794   LÊ THỊ THU HẰNG      GM
# 61656      RM  60011794   LÊ THỊ THU HẰNG      GM
# 58522      RM  60011794   LÊ THỊ THU HẰNG      GM
# 58514      RM  60011794   LÊ THỊ THU HẰNG      GM
# 62510      DM  60012256       LÊ VĂN TUYẾN      RM
#
# [5 rows x 28 columns]

# %%
level_9 = pd.merge(level_8, parent_sup_short, left_on = 'L8Code', right_on = 'Agent_Number', how = 'left')
level_9 = level_9.loc[:,level_9.columns != 'Agent_Number'].rename(columns={'HigherCode':"L9Code",
                                                        "HigherName":"L9Name", "HigherGrade":"L9Grade", "CUTOFF_x": "CUTOFF"})
level_9.sort_values('L9Code').head(5)
# Out:
#          CUTOFF AgentNumber                 AgentName AgentGrade    L1Code  \
# 62510  20240126    60054379  PHẠM THỊ BÍCH PHƯỢNG         FC  60052425
# 59216  20240126    60054438   NGUYỄN THỊ ÚT TƯỜNG         FC  60054379
# 60998  20240126    60055426        NGUYỄN ĐỨC ĐÌNH         FC  60054438
# 31839  20240126    60081068         NGUYỄN KHÁNH LY         FC  60078000
# 38399  20240126    60081847       TRẦN THỊ MAI LIÊN         FC  60081845
#
#                           L1Name L1Grade    L2Code                     L2Name  \
# 62510                LÊ THỊ TỊ      FC  60052313     TRẦN THỊ THÙY TRANG
# 59216   PHẠM THỊ BÍCH PHƯỢNG      FC  60052425                LÊ THỊ TỊ
# 60998    NGUYỄN THỊ ÚT TƯỜNG      FC  60054379   PHẠM THỊ BÍCH PHƯỢNG
# 31839   TRẦN HOÀNG PHƯƠNG UYÊN      FC  60076295          ĐINH THANH PHƯƠNG
# 38399   NGUYỄN ÁI HUYỀN TRANG      FC  60081846            NGUYỄN GIA HUY
#
#       L2Grade  ... L6Grade    L7Code                     L7Name L7Grade  \
# 62510      FC  ...      DM  60026501        ĐÀO THỊ UYỂN NHI      DM
# 59216      FC  ...      FM  60039893      BÙI THỊ BÍCH LIỄU      DM
# 60998      FC  ...      FM  60054381               LÊ SĨ KHANG      FM
# 31839      FC  ...      RM  60075020          HÀ HOÀNG NGUYÊN      RM
# 38399      FC  ...      FM  60066939   NGUYỄN HOÀNG THANH NHI      DM
#
#          L8Code                   L8Name L8Grade    L9Code  \
# 62510  60012256            LÊ VĂN TUYẾN      RM  60011794
# 59216  60026501      ĐÀO THỊ UYỂN NHI      DM  60012256
# 60998  60039893    BÙI THỊ BÍCH LIỄU      DM  60026501
# 31839  60075021            HÀ TẤN NGHI      RM  60037558
# 38399  60066190   LIÊU THỊ TUYẾT TRANG      DM  60057467
#
#                      L9Name L9Grade
# 62510     LÊ THỊ THU HẰNG      GM
# 59216         LÊ VĂN TUYẾN      RM
# 60998   ĐÀO THỊ UYỂN NHI      DM
# 31839    NGUYỄN TRÍ HÙNG      GM
# 38399        VƯƠNG THỊ TÂM      RM
#
# [5 rows x 31 columns]

# %%
level_10 = pd.merge(level_9, parent_sup_short, left_on = 'L9Code', right_on = 'Agent_Number', how = 'left')
level_10 = level_10.loc[:,level_10.columns != 'Agent_Number'].rename(columns={'HigherCode':"L10Code",
                                                        "HigherName":"L10Name", "HigherGrade":"L10Grade", "CUTOFF_x": "CUTOFF"})
level_10.sort_values('L10Code').head(5)
# Out:
#          CUTOFF AgentNumber                AgentName AgentGrade    L1Code  \
# 59216  20240126    60054438  NGUYỄN THỊ ÚT TƯỜNG         FC  60054379
# 60998  20240126    60055426       NGUYỄN ĐỨC ĐÌNH         FC  60054438
# 0      20240126    60016738        NGUYỄN VĂN HIỀN         FC  60013747
# 1      20240126    60019723             LÊ VĂN HIỀN         FM  60015473
# 2      20240126    60014363           VŨ THỊ HOÀI         FM  60013747
#
#                           L1Name L1Grade    L2Code                     L2Name  \
# 59216   PHẠM THỊ BÍCH PHƯỢNG      FC  60052425                LÊ THỊ TỊ
# 60998    NGUYỄN THỊ ÚT TƯỜNG      FC  60054379   PHẠM THỊ BÍCH PHƯỢNG
# 0                 ĐẶNG LONG TÂN      FM       NaN                        NaN
# 1                  VŨ THỊ THÀ      FM       NaN                        NaN
# 2                 ĐẶNG LONG TÂN      FM       NaN                        NaN
#
#       L2Grade  ... L7Grade    L8Code                  L8Name L8Grade  \
# 59216      FC  ...      DM  60026501     ĐÀO THỊ UYỂN NHI      DM
# 60998      FC  ...      FM  60039893   BÙI THỊ BÍCH LIỄU      DM
# 0         NaN  ...     NaN       NaN                     NaN     NaN
# 1         NaN  ...     NaN       NaN                     NaN     NaN
# 2         NaN  ...     NaN       NaN                     NaN     NaN
#
#          L9Code                L9Name L9Grade   L10Code             L10Name  \
# 59216  60012256         LÊ VĂN TUYẾN      RM  60011794   LÊ THỊ THU HẰNG
# 60998  60026501   ĐÀO THỊ UYỂN NHI      DM  60012256       LÊ VĂN TUYẾN
# 0           NaN                   NaN     NaN       NaN                 NaN
# 1           NaN                   NaN     NaN       NaN                 NaN
# 2           NaN                   NaN     NaN       NaN                 NaN
#
#       L10Grade
# 59216       GM
# 60998       RM
# 0          NaN
# 1          NaN
# 2          NaN
#
# [5 rows x 34 columns]

# %%
level_11 = pd.merge(level_10, parent_sup_short, left_on = 'L10Code', right_on = 'Agent_Number', how = 'left')
level_11 = level_11.loc[:,level_11.columns != 'Agent_Number'].rename(columns={'HigherCode':"L11Code",
                                                        "HigherName":"L11Name", "HigherGrade":"L11Grade", "CUTOFF_x": "CUTOFF"})
level_11.sort_values('L11Code').head(5)
# Out:
#          CUTOFF AgentNumber           AgentName AgentGrade    L1Code  \
# 60998  20240126    60055426  NGUYỄN ĐỨC ĐÌNH         FC  60054438
# 0      20240126    60016738   NGUYỄN VĂN HIỀN         FC  60013747
# 1      20240126    60019723        LÊ VĂN HIỀN         FM  60015473
# 2      20240126    60014363      VŨ THỊ HOÀI         FM  60013747
# 3      20240126    60019844    NGUYỄN THỊ LEN         FC  60019724
#
#                          L1Name L1Grade    L2Code                     L2Name  \
# 60998   NGUYỄN THỊ ÚT TƯỜNG      FC  60054379   PHẠM THỊ BÍCH PHƯỢNG
# 0                ĐẶNG LONG TÂN      FM       NaN                        NaN
# 1                 VŨ THỊ THÀ      FM       NaN                        NaN
# 2                ĐẶNG LONG TÂN      FM       NaN                        NaN
# 3              PHẠM THỊ QUYÊN      FM  60015473              VŨ THỊ THÀ
#
#       L2Grade  ... L8Grade    L9Code                L9Name L9Grade   L10Code  \
# 60998      FC  ...      DM  60026501   ĐÀO THỊ UYỂN NHI      DM  60012256
# 0         NaN  ...     NaN       NaN                   NaN     NaN       NaN
# 1         NaN  ...     NaN       NaN                   NaN     NaN       NaN
# 2         NaN  ...     NaN       NaN                   NaN     NaN       NaN
# 3          FM  ...     NaN       NaN                   NaN     NaN       NaN
#
#               L10Name L10Grade   L11Code             L11Name L11Grade
# 60998   LÊ VĂN TUYẾN       RM  60011794   LÊ THỊ THU HẰNG       GM
# 0                 NaN      NaN       NaN                 NaN      NaN
# 1                 NaN      NaN       NaN                 NaN      NaN
# 2                 NaN      NaN       NaN                 NaN      NaN
# 3                 NaN      NaN       NaN                 NaN      NaN
#
# [5 rows x 37 columns]

# %%
level_12 = pd.merge(level_11, parent_sup_short, left_on = 'L11Code', right_on = 'Agent_Number', how = 'left')
level_12 = level_12.loc[:,level_12.columns != 'Agent_Number'].rename(columns={'HigherCode':"L12Code",
                                                        "HigherName":"L12Name", "HigherGrade":"L12Grade", "CUTOFF_x": "CUTOFF"})
level_12.sort_values('L12Code').head(5)
# Out:
#      CUTOFF AgentNumber           AgentName AgentGrade    L1Code  \
# 0  20240126    60016738   NGUYỄN VĂN HIỀN         FC  60013747
# 1  20240126    60019723        LÊ VĂN HIỀN         FM  60015473
# 2  20240126    60014363      VŨ THỊ HOÀI         FM  60013747
# 3  20240126    60019844    NGUYỄN THỊ LEN         FC  60019724
# 4  20240126    60012715  LƯU THỊ THU HƯƠNG         FC  60012707
#
#                  L1Name L1Grade    L2Code          L2Name L2Grade  ...  \
# 0        ĐẶNG LONG TÂN      FM       NaN             NaN     NaN  ...
# 1         VŨ THỊ THÀ      FM       NaN             NaN     NaN  ...
# 2        ĐẶNG LONG TÂN      FM       NaN             NaN     NaN  ...
# 3      PHẠM THỊ QUYÊN      FM  60015473   VŨ THỊ THÀ      FM  ...
# 4   ĐINH THỊ THU THANH      FM       NaN             NaN     NaN  ...
#
#   L9Grade L10Code L10Name L10Grade L11Code L11Name L11Grade L12Code L12Name  \
# 0     NaN     NaN     NaN      NaN     NaN     NaN      NaN     NaN     NaN
# 1     NaN     NaN     NaN      NaN     NaN     NaN      NaN     NaN     NaN
# 2     NaN     NaN     NaN      NaN     NaN     NaN      NaN     NaN     NaN
# 3     NaN     NaN     NaN      NaN     NaN     NaN      NaN     NaN     NaN
# 4     NaN     NaN     NaN      NaN     NaN     NaN      NaN     NaN     NaN
#
#   L12Grade
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#
# [5 rows x 40 columns]

# %%
level_13 = pd.merge(level_12, parent_sup_short, left_on = 'L12Code', right_on = 'Agent_Number', how = 'left')
level_13 = level_13.loc[:,level_13.columns != 'Agent_Number'].rename(columns={'HigherCode':"L13Code",
                                                        "HigherName":"L13Name", "HigherGrade":"L13Grade", "CUTOFF_x": "CUTOFF"})
final_tree = level_13
final_tree.sort_values('L13Code').head(5)
#Double check if the highest level is over
# Out:
#      CUTOFF AgentNumber           AgentName AgentGrade    L1Code  \
# 0  20240126    60016738   NGUYỄN VĂN HIỀN         FC  60013747
# 1  20240126    60019723        LÊ VĂN HIỀN         FM  60015473
# 2  20240126    60014363      VŨ THỊ HOÀI         FM  60013747
# 3  20240126    60019844    NGUYỄN THỊ LEN         FC  60019724
# 4  20240126    60012715  LƯU THỊ THU HƯƠNG         FC  60012707
#
#                  L1Name L1Grade    L2Code          L2Name L2Grade  ...  \
# 0        ĐẶNG LONG TÂN      FM       NaN             NaN     NaN  ...
# 1         VŨ THỊ THÀ      FM       NaN             NaN     NaN  ...
# 2        ĐẶNG LONG TÂN      FM       NaN             NaN     NaN  ...
# 3      PHẠM THỊ QUYÊN      FM  60015473   VŨ THỊ THÀ      FM  ...
# 4   ĐINH THỊ THU THANH      FM       NaN             NaN     NaN  ...
#
#   L10Grade L11Code L11Name L11Grade L12Code L12Name L12Grade L13Code L13Name  \
# 0      NaN     NaN     NaN      NaN     NaN     NaN      NaN     NaN     NaN
# 1      NaN     NaN     NaN      NaN     NaN     NaN      NaN     NaN     NaN
# 2      NaN     NaN     NaN      NaN     NaN     NaN      NaN     NaN     NaN
# 3      NaN     NaN     NaN      NaN     NaN     NaN      NaN     NaN     NaN
# 4      NaN     NaN     NaN      NaN     NaN     NaN      NaN     NaN     NaN
#
#   L13Grade
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#
# [5 rows x 43 columns]

# %% [markdown]
# <h3> Tách ra các cấp <h3>

# %%
#Lấy ra FM
final_tree.loc[final_tree['AgentGrade'] == "FM", 'FM_Code'] = final_tree['AgentNumber']
final_tree.loc[final_tree['AgentGrade'] == "FM", 'FM_Name'] = final_tree['AgentName']
#loc[final_tree['AgentGrade'] == "FM", 'FM_Code'] = final_tree['AgentNumber']
#[final_tree['AgentGrade'] == "FM", 'FM_Code'] => add the column named FM_Code with the condition AgentGrade = "FM"
#... = final_tree['AgentNumber'] > "FM_Code" = 'AgentNumber'
final_tree.sort_values('FM_Code').head(5)
# Out:
#          CUTOFF AgentNumber            AgentName AgentGrade    L1Code  \
# 36145  20240126    60000055  ĐINH HỒ QUANG VINH         FM  60000036
# 350    20240126    60000101     BÙI THỊ HƯỜNG         FM  60000092
# 29680  20240126    60000189      TÔ ĐÌNH TRỌNG         FM  60000194
# 63980  20240126    60000197      TĂNG THỊ NHÀN         FM  60000231
# 63300  20240126    60000198      LÝ THỤC TRANG         FM  60000231
#
#                             L1Name L1Grade    L2Code                  L2Name  \
# 36145               PHẠM HI PHÚC      AM  60000933   TRẦN THỊ XUÂN KIỀU
# 350               NGUYỄN THỊ THU      DM       NaN                     NaN
# 29680            TRƯƠNG THỊ HẰNG      FC       NaN                     NaN
# 63980   TRƯƠNG NGUYỄN MẠNH CƯƠNG      DM       NaN                     NaN
# 63300   TRƯƠNG NGUYỄN MẠNH CƯƠNG      DM       NaN                     NaN
#
#       L2Grade  ... L11Name L11Grade L12Code L12Name L12Grade L13Code L13Name  \
# 36145      FC  ...     NaN      NaN     NaN     NaN      NaN     NaN     NaN
# 350       NaN  ...     NaN      NaN     NaN     NaN      NaN     NaN     NaN
# 29680     NaN  ...     NaN      NaN     NaN     NaN      NaN     NaN     NaN
# 63980     NaN  ...     NaN      NaN     NaN     NaN      NaN     NaN     NaN
# 63300     NaN  ...     NaN      NaN     NaN     NaN      NaN     NaN     NaN
#
#       L13Grade   FM_Code              FM_Name
# 36145      NaN  60000055  ĐINH HỒ QUANG VINH
# 350        NaN  60000101     BÙI THỊ HƯỜNG
# 29680      NaN  60000189      TÔ ĐÌNH TRỌNG
# 63980      NaN  60000197      TĂNG THỊ NHÀN
# 63300      NaN  60000198      LÝ THỤC TRANG
#
# [5 rows x 45 columns]

# %%
#List code
code_lst = [ ("L" +str(i)+"Code") for i in range(13,0,-1)]
name_lst = [ ("L" +str(i)+"Name") for i in range(13,0,-1)]
grade_lst = [ ("L" +str(i)+"Grade") for i in range(13,0,-1)]
for code,name, grade in zip(code_lst, name_lst, grade_lst):
    print(code, name, grade)
# Out:
# L13Code L13Name L13Grade
# L12Code L12Name L12Grade
# L11Code L11Name L11Grade
# L10Code L10Name L10Grade
# L9Code L9Name L9Grade
# L8Code L8Name L8Grade
# L7Code L7Name L7Grade
# L6Code L6Name L6Grade
# L5Code L5Name L5Grade
# L4Code L4Name L4Grade
# L3Code L3Name L3Grade
# L2Code L2Name L2Grade
# L1Code L1Name L1Grade

# %%
for code,name, grade in zip(code_lst, name_lst, grade_lst):
    final_tree.loc[(final_tree[grade] == "FM") & (final_tree[grade] != final_tree['AgentGrade']), "FM_Code"] = final_tree[code]
    final_tree.loc[(final_tree[grade] == "FM") & (final_tree[grade] != final_tree['AgentGrade']), "FM_Name"] = final_tree[name]

final_tree[final_tree['AgentGrade']=="FM"].sort_values('FM_Code')
# Out:
#          CUTOFF AgentNumber                     AgentName AgentGrade  \
# 36145  20240126    60000055           ĐINH HỒ QUANG VINH         FM
# 350    20240126    60000101              BÙI THỊ HƯỜNG         FM
# 29680  20240126    60000189               TÔ ĐÌNH TRỌNG         FM
# 63980  20240126    60000197               TĂNG THỊ NHÀN         FM
# 63300  20240126    60000198               LÝ THỤC TRANG         FM
# ...         ...         ...                           ...        ...
# 15498  20240126    60083664              HUỲNH TUẤN ANH         FM
# 54891  20240126    60083675        NGUYỄN THỊ MINH HỢP         FM
# 53839  20240126    60083676             LÊ THỊ HÀ THỦY         FM
# 19423  20240126    60083677               NGUYỄN VĂN VŨ         FM
# 41622  20240126    60083681  DUMMY NGUYỄN THỊ NGỌC MỸ         FM
#
#          L1Code                       L1Name L1Grade    L2Code  \
# 36145  60000036               PHẠM HI PHÚC      AM  60000933
# 350    60000092             NGUYỄN THỊ THU      DM       NaN
# 29680  60000194            TRƯƠNG THỊ HẰNG      FC       NaN
# 63980  60000231   TRƯƠNG NGUYỄN MẠNH CƯƠNG      DM       NaN
# 63300  60000231   TRƯƠNG NGUYỄN MẠNH CƯƠNG      DM       NaN
# ...         ...                          ...     ...       ...
# 15498  60072718             NGUYỄN THỊ ẨN      DM       NaN
# 54891  60082611           PHAN LÊ ÁNH NHẬT      FM  60081245
# 53839  60080235      NGUYỄN THỊ QUÝ HƯƠNG      FM  60080329
# 19423  60083678      HUỲNH THỊ TRÚC GIANG      DM  60080389
# 41622  60083660      DUMMY NGUYỄN TƯỜNG VY      DM  60083626
#
#                        L2Name L2Grade  ... L11Name L11Grade L12Code L12Name  \
# 36145   TRẦN THỊ XUÂN KIỀU      FC  ...     NaN      NaN     NaN     NaN
# 350                       NaN     NaN  ...     NaN      NaN     NaN     NaN
# 29680                     NaN     NaN  ...     NaN      NaN     NaN     NaN
# 63980                     NaN     NaN  ...     NaN      NaN     NaN     NaN
# 63300                     NaN     NaN  ...     NaN      NaN     NaN     NaN
# ...                       ...     ...  ...     ...      ...     ...     ...
# 15498                     NaN     NaN  ...     NaN      NaN     NaN     NaN
# 54891   PHẠM QUỐC TẤN ĐẠT      FM  ...     NaN      NaN     NaN     NaN
# 53839           TRƯƠNG THUẬN      DM  ...     NaN      NaN     NaN     NaN
# 19423          CHÂU THỊ HỢP      DM  ...     NaN      NaN     NaN     NaN
# 41622     DUMMY LÊ DUY KHÁNH      DM  ...     NaN      NaN     NaN     NaN
#
#       L12Grade L13Code L13Name L13Grade   FM_Code  \
# 36145      NaN     NaN     NaN      NaN  60000055
# 350        NaN     NaN     NaN      NaN  60000101
# 29680      NaN     NaN     NaN      NaN  60000189
# 63980      NaN     NaN     NaN      NaN  60000197
# 63300      NaN     NaN     NaN      NaN  60000198
# ...        ...     ...     ...      ...       ...
# 15498      NaN     NaN     NaN      NaN  60083664
# 54891      NaN     NaN     NaN      NaN  60083675
# 53839      NaN     NaN     NaN      NaN  60083676
# 19423      NaN     NaN     NaN      NaN  60083677
# 41622      NaN     NaN     NaN      NaN  60083681
#
#                             FM_Name
# 36145           ĐINH HỒ QUANG VINH
# 350                BÙI THỊ HƯỜNG
# 29680               TÔ ĐÌNH TRỌNG
# 63980               TĂNG THỊ NHÀN
# 63300               LÝ THỤC TRANG
# ...                             ...
# 15498              HUỲNH TUẤN ANH
# 54891        NGUYỄN THỊ MINH HỢP
# 53839             LÊ THỊ HÀ THỦY
# 19423               NGUYỄN VĂN VŨ
# 41622  DUMMY NGUYỄN THỊ NGỌC MỸ
#
# [7095 rows x 45 columns]

# %%
#Lấy ra FM
final_tree.loc[final_tree['AgentGrade'] == "FM", 'FM_Code'] = final_tree['AgentNumber']
final_tree.loc[final_tree['AgentGrade'] == "FM", 'FM_Name'] = final_tree['AgentName']
#Lấy ra DM
final_tree.loc[final_tree['AgentGrade'] == "DM", 'DM_Code'] = final_tree['AgentNumber']
final_tree.loc[final_tree['AgentGrade'] == "DM", 'DM_Name'] = final_tree['AgentName']
#Lấy ra RM
final_tree.loc[final_tree['AgentGrade'] == "RM", 'RM_Code'] = final_tree['AgentNumber']
final_tree.loc[final_tree['AgentGrade'] == "RM", 'RM_Name'] = final_tree['AgentName']
#Lấy ra GM
final_tree.loc[final_tree['AgentGrade'] == "GM", 'GM_Code'] = final_tree['AgentNumber']
final_tree.loc[final_tree['AgentGrade'] == "GM", 'GM_Name'] = final_tree['AgentName']
#List code
code_lst = [ ("L" +str(i)+"Code") for i in range(13,0,-1)]
name_lst = [ ("L" +str(i)+"Name") for i in range(13,0,-1)]
grade_lst = [ ("L" +str(i)+"Grade") for i in range(13,0,-1)]
for code,name, grade in zip(code_lst, name_lst, grade_lst):
    final_tree.loc[(final_tree[grade] == "FM") & (final_tree[grade] != final_tree['AgentGrade']), "FM_Code"] = final_tree[code]
    final_tree.loc[(final_tree[grade] == "FM") & (final_tree[grade] != final_tree['AgentGrade']), "FM_Name"] = final_tree[name]
    #
    final_tree.loc[(final_tree[grade] == "DM") & (final_tree[grade] != final_tree['AgentGrade']), "DM_Code"] = final_tree[code]
    final_tree.loc[(final_tree[grade] == "DM") & (final_tree[grade] != final_tree['AgentGrade']), "DM_Name"] = final_tree[name]
    #
    final_tree.loc[(final_tree[grade] == "RM") & (final_tree[grade] != final_tree['AgentGrade']), "RM_Code"] = final_tree[code]
    final_tree.loc[(final_tree[grade] == "RM") & (final_tree[grade] != final_tree['AgentGrade']), "RM_Name"] = final_tree[name]
    #
    final_tree.loc[(final_tree[grade] == "GM") & (final_tree[grade] != final_tree['AgentGrade']), "GM_Code"] = final_tree[code]
    final_tree.loc[(final_tree[grade] == "GM") & (final_tree[grade] != final_tree['AgentGrade']), "GM_Name"] = final_tree[name]
    #
change_grade = ['AM', 'IS', 'IG', 'ID', 'EA', 'PA']
for grad in change_grade:
    final_tree['AgentGrade'] = final_tree['AgentGrade'].replace(grad, "FC")
final_tree
# Out:
#          CUTOFF AgentNumber                    AgentName AgentGrade    L1Code  \
# 0      20240126    60016738            NGUYỄN VĂN HIỀN         FC  60013747
# 1      20240126    60019723                 LÊ VĂN HIỀN         FM  60015473
# 2      20240126    60014363               VŨ THỊ HOÀI         FM  60013747
# 3      20240126    60019844             NGUYỄN THỊ LEN         FC  60019724
# 4      20240126    60012715           LƯU THỊ THU HƯƠNG         FC  60012707
# ...         ...         ...                          ...        ...       ...
# 68716  20240126    60015914          NGUYỄN ĐÌNH HOÀN         FC  60012728
# 68717  20240126    60018135  PHAN NGUYỄN LÊ THIÊN HƯƠNG         FC  60013120
# 68718  20240126    60013527                  ĐIỂU KHƯƠI         FC  60013383
# 68719  20240126    60019184     TRẦN THỊ BÍCH PHƯỢNG         FC  60019183
# 68720  20240126    60012465          NGUYỄN THỊ HƯỜNG         FC  60010702
#
#                      L1Name L1Grade    L2Code             L2Name L2Grade  ...  \
# 0            ĐẶNG LONG TÂN      FM       NaN                NaN     NaN  ...
# 1             VŨ THỊ THÀ      FM       NaN                NaN     NaN  ...
# 2            ĐẶNG LONG TÂN      FM       NaN                NaN     NaN  ...
# 3          PHẠM THỊ QUYÊN      FM  60015473      VŨ THỊ THÀ      FM  ...
# 4       ĐINH THỊ THU THANH      FM       NaN                NaN     NaN  ...
# ...                     ...     ...       ...                ...     ...  ...
# 68716        VŨ THỊ CHUNG      FC       NaN                NaN     NaN  ...
# 68717          ĐÀO ANH TÚ      FC       NaN                NaN     NaN  ...
# 68718           DUMMY 13383      DM       NaN                NaN     NaN  ...
# 68719   LÊ THỊ NGỌC HƯƠNG      FC       NaN                NaN     NaN  ...
# 68720         CAO THỊ CÚC      FC  60006494   ĐINH THỊ NGUYÊN      DM  ...
#
#       L13Name L13Grade   FM_Code               FM_Name   DM_Code  \
# 0         NaN      NaN  60013747        ĐẶNG LONG TÂN       NaN
# 1         NaN      NaN  60019723          LÊ VĂN HIỀN       NaN
# 2         NaN      NaN  60014363        VŨ THỊ HOÀI       NaN
# 3         NaN      NaN  60019724      PHẠM THỊ QUYÊN       NaN
# 4         NaN      NaN  60012707   ĐINH THỊ THU THANH       NaN
# ...       ...      ...       ...                   ...       ...
# 68716     NaN      NaN       NaN                   NaN       NaN
# 68717     NaN      NaN       NaN                   NaN       NaN
# 68718     NaN      NaN       NaN                   NaN  60013383
# 68719     NaN      NaN       NaN                   NaN       NaN
# 68720     NaN      NaN       NaN                   NaN  60006494
#
#                  DM_Name RM_Code RM_Name GM_Code GM_Name
# 0                    NaN     NaN     NaN     NaN     NaN
# 1                    NaN     NaN     NaN     NaN     NaN
# 2                    NaN     NaN     NaN     NaN     NaN
# 3                    NaN     NaN     NaN     NaN     NaN
# 4                    NaN     NaN     NaN     NaN     NaN
# ...                  ...     ...     ...     ...     ...
# 68716                NaN     NaN     NaN     NaN     NaN
# 68717                NaN     NaN     NaN     NaN     NaN
# 68718        DUMMY 13383     NaN     NaN     NaN     NaN
# 68719                NaN     NaN     NaN     NaN     NaN
# 68720   ĐINH THỊ NGUYÊN     NaN     NaN     NaN     NaN
#
# [68721 rows x 51 columns]

# %% [markdown]
# <h3> Bóc ra các cột cần thiết <h3>

# %%
final_tree.columns
# Out:
# Index(['CUTOFF', 'AgentNumber', 'AgentName', 'AgentGrade', 'L1Code', 'L1Name',
#        'L1Grade', 'L2Code', 'L2Name', 'L2Grade', 'L3Code', 'L3Name', 'L3Grade',
#        'L4Code', 'L4Name', 'L4Grade', 'L5Code', 'L5Name', 'L5Grade', 'L6Code',
#        'L6Name', 'L6Grade', 'L7Code', 'L7Name', 'L7Grade', 'L8Code', 'L8Name',
#        'L8Grade', 'L9Code', 'L9Name', 'L9Grade', 'L10Code', 'L10Name',
#        'L10Grade', 'L11Code', 'L11Name', 'L11Grade', 'L12Code', 'L12Name',
#        'L12Grade', 'L13Code', 'L13Name', 'L13Grade', 'FM_Code', 'FM_Name',
#        'DM_Code', 'DM_Name', 'RM_Code', 'RM_Name', 'GM_Code', 'GM_Name'],
#       dtype='object')

# %%
Agent_List = final_tree[['GM_Code', 'GM_Name', 'RM_Code', 'RM_Name', 'DM_Code', 'DM_Name', 'FM_Code', 'FM_Name',
        'CUTOFF', 'AgentNumber', 'AgentName', 'AgentGrade']]
Agent_List
# Out:
#       GM_Code GM_Name RM_Code RM_Name   DM_Code            DM_Name   FM_Code  \
# 0         NaN     NaN     NaN     NaN       NaN                NaN  60013747
# 1         NaN     NaN     NaN     NaN       NaN                NaN  60019723
# 2         NaN     NaN     NaN     NaN       NaN                NaN  60014363
# 3         NaN     NaN     NaN     NaN       NaN                NaN  60019724
# 4         NaN     NaN     NaN     NaN       NaN                NaN  60012707
# ...       ...     ...     ...     ...       ...                ...       ...
# 68716     NaN     NaN     NaN     NaN       NaN                NaN       NaN
# 68717     NaN     NaN     NaN     NaN       NaN                NaN       NaN
# 68718     NaN     NaN     NaN     NaN  60013383        DUMMY 13383       NaN
# 68719     NaN     NaN     NaN     NaN       NaN                NaN       NaN
# 68720     NaN     NaN     NaN     NaN  60006494   ĐINH THỊ NGUYÊN       NaN
#
#                     FM_Name    CUTOFF AgentNumber  \
# 0            ĐẶNG LONG TÂN  20240126    60016738
# 1              LÊ VĂN HIỀN  20240126    60019723
# 2            VŨ THỊ HOÀI  20240126    60014363
# 3          PHẠM THỊ QUYÊN  20240126    60019844
# 4       ĐINH THỊ THU THANH  20240126    60012715
# ...                     ...       ...         ...
# 68716                   NaN  20240126    60015914
# 68717                   NaN  20240126    60018135
# 68718                   NaN  20240126    60013527
# 68719                   NaN  20240126    60019184
# 68720                   NaN  20240126    60012465
#
#                          AgentName AgentGrade
# 0                NGUYỄN VĂN HIỀN         FC
# 1                     LÊ VĂN HIỀN         FM
# 2                   VŨ THỊ HOÀI         FM
# 3                 NGUYỄN THỊ LEN         FC
# 4               LƯU THỊ THU HƯƠNG         FC
# ...                            ...        ...
# 68716          NGUYỄN ĐÌNH HOÀN         FC
# 68717  PHAN NGUYỄN LÊ THIÊN HƯƠNG         FC
# 68718                  ĐIỂU KHƯƠI         FC
# 68719     TRẦN THỊ BÍCH PHƯỢNG         FC
# 68720          NGUYỄN THỊ HƯỜNG         FC
#
# [68721 rows x 12 columns]
